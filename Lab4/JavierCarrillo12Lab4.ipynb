# %% [markdown]
# <a href="https://colab.research.google.com/github/JavierCarrillo12/MetNumUN2023II/blob/main/Lab4/JavierCarrillo12Lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SymPyLab
#
# SymPy’s documentation
# - https://docs.sympy.org/latest/index.html

# %% [markdown]
# Javier Carrillo
# ## ID - Last Digit 3

# %% [markdown]
# ### **Our own polynomial**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol
from sympy import div

x = Symbol('x')

p = x**10 - 94*x**9  + 3474*x**8 - 66444*x**7 + 744177*x**6 - 5179566*x**5 + 22877756*x**4 - 63479336*x**3 + 105620352*x**2 - 94389120*x + 33868800

p, r = div(p,  x+28)

print(p)
print(r)
print()

p, r = div(p,  x+1)

print(p)
print(r)
print()

p, r = div(p,  x+2)

print(p)
print(r)
print()

p, r = div(p,  x+5)

print(p)
print(r)
print()
# Out:
# x**9 - 122*x**8 + 6890*x**7 - 259364*x**6 + 8006369*x**5 - 229357898*x**4 + 6444898900*x**3 - 180520648536*x**2 + 5054683779360*x - 141531240211200
# 3962874759782400
#
# x**8 - 123*x**7 + 7013*x**6 - 266377*x**5 + 8272746*x**4 - 237630644*x**3 + 6682529544*x**2 - 187203178080*x + 5241886957440
# -146773127168640
#
# x**7 - 125*x**6 + 7263*x**5 - 280903*x**4 + 8834552*x**3 - 255299748*x**2 + 7193129040*x - 201589436160
# 5645065829760
#
# x**6 - 130*x**5 + 7913*x**4 - 320468*x**3 + 10436892*x**2 - 307484208*x + 8730550080
# -245242186560

# %%
p = x**10 - 94*x**9  + 3474*x**8 - 66444*x**7 + 744177*x**6 - 5179566*x**5 + 22877756*x**4 - 63479336*x**3 + 105320352*x**2 - 94389120*x + 33868800

p, r = div(p,  x+2)

print(p)
print(r)
# Out:
# x**9 - 96*x**8 + 3666*x**7 - 73776*x**6 + 891729*x**5 - 6963024*x**4 + 36803804*x**3 - 137086944*x**2 + 379494240*x - 853377600
# 1740624000

# %% [markdown]
# ## SymPy’s polynomial simple univariate polynomial factorization
# - https://docs.sympy.org/latest/modules/polys/wester.html#simple-univariate-polynomial-factorization
# - factor(x\*\*10 - 121\*x\*\*9  + 5796\*x\*\*8 - 141666\*x\*\*7 + 1936389\*x\*\*6 - 15734649\*x\*\*5 + 78285374\*x\*\*4 - 237917804\*x\*\*3 + 424054680\*x\*\*2 -398664000\*x +148176000)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**10 - 94*x**9  + 3474*x**8 - 66444*x**7 + 744177*x**6 - 5179566*x**5 + 22877756*x**4 - 63479336*x**3 + 105320352*x**2 - 94389120*x + 33868800)
# Out:
# x**10 - 94*x**9 + 3474*x**8 - 66444*x**7 + 744177*x**6 - 5179566*x**5 + 22877756*x**4 - 63479336*x**3 + 105320352*x**2 - 94389120*x + 33868800

# %% [markdown]
# ## SymPy’s solvers
# - https://docs.sympy.org/latest/tutorial/solvers.html
# - x\*\*10 - 94*x\*\*9  + 3474*x\*\*8 - 66444*x\*\*7 + 744177*x\*\*6 - 5179566*x\*\*5 + 22877756*x\*\*4 - 63479336*x\*\*3 + 105320352*x\*\*2 - 94389120\*x + 33868800

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq
x = Symbol('x')
solveset(Eq(x**10 - 94*x**9  + 3474*x**8 - 66444*x**7 + 744177*x**6 - 5179566*x**5 + 22877756*x**4 - 63479336*x**3 + 105320352*x**2 - 94389120*x + 33868800, 0), x)
# Out:
# {CRootOf(x**10 - 94*x**9 + 3474*x**8 - 66444*x**7 + 744177*x**6 - 5179566*x**5 + 22877756*x**4 - 63479336*x**3 + 105320352*x**2 - 94389120*x + 33868800, 0), CRootOf(x**10 - 94*x**9 + 3474*x**8 - 66444*x**7 + 744177*x**6 - 5179566*x**5 + 22877756*x**4 - 63479336*x**3 + 105320352*x**2 - 94389120*x + 33868800, 1), CRootOf(x**10 - 94*x**9 + 3474*x**8 - 66444*x**7 + 744177*x**6 - 5179566*x**5 + 22877756*x**4 - 63479336*x**3 + 105320352*x**2 - 94389120*x + 33868800, 2), CRootOf(x**10 - 94*x**9 + 3474*x**8 - 66444*x**7 + 744177*x**6 - 5179566*x**5 + 22877756*x**4 - 63479336*x**3 + 105320352*x**2 - 94389120*x + 33868800, 3), CRootOf(x**10 - 94*x**9 + 3474*x**8 - 66444*x**7 + 744177*x**6 - 5179566*x**5 + 22877756*x**4 - 63479336*x**3 + 105320352*x**2 - 94389120*x + 33868800, 4), CRootOf(x**10 - 94*x**9 + 3474*x**8 - 66444*x**7 + 744177*x**6 - 5179566*x**5 + 22877756*x**4 - 63479336*x**3 + 105320352*x**2 - 94389120*x + 33868800, 5), CRootOf(x**10 - 94*x**9 + 3474*x**8 - 66444*x**7 + 744177*x**6 - 5179566*x**5 + 22877756*x**4 - 63479336*x**3 + 105320352*x**2 - 94389120*x + 33868800, 6), CRootOf(x**10 - 94*x**9 + 3474*x**8 - 66444*x**7 + 744177*x**6 - 5179566*x**5 + 22877756*x**4 - 63479336*x**3 + 105320352*x**2 - 94389120*x + 33868800, 7), CRootOf(x**10 - 94*x**9 + 3474*x**8 - 66444*x**7 + 744177*x**6 - 5179566*x**5 + 22877756*x**4 - 63479336*x**3 + 105320352*x**2 - 94389120*x + 33868800, 8), CRootOf(x**10 - 94*x**9 + 3474*x**8 - 66444*x**7 + 744177*x**6 - 5179566*x**5 + 22877756*x**4 - 63479336*x**3 + 105320352*x**2 - 94389120*x + 33868800, 9)}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq, sqrt, pi, E
x = Symbol('x')
solveset(Eq(x**2*pi - (pi+sqrt(8))+ (sqrt(2)+pi), 0), x)
# Out:
# {-2**(1/4)/sqrt(pi), 2**(1/4)/sqrt(pi)}

# %% [markdown]
# *   Reference docs for the Poly Domains https://docs.sympy.org/dev/modules/polys/domainsref.html
#
# *   Introducing the Domains of the poly module https://docs.sympy.org/dev/modules/polys/domainsintro.html
#
# *   Internals of the Polynomial Manipulation Module https://docs.sympy.org/latest/modules/polys/internals.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**10 - 94*x**9  + 3474*x**8 - 66444*x**7 + 744177*x**6 - 5179566*x**5 + 22877756*x**4 - 63479336*x**3 + 105620352*x**2 - 94389120*x + 33868800,domain='GF(3)')
# Out:
# x**3*(x - 1)**4*(x + 1)**3

# %% [markdown]
# ## Wolfram alpha answers quastion in natural languaje
# "What is the total area of the Great Wall of China?"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Try the same question asked in Wolfram Alpha in ChatGPT
#
# https://chat.openai.com/auth/login
#
# and post the answer screenshoot.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## SymPy’s integrate

# %% [markdown]
# ![image.png](data:image/png;base64,...)![image.png](
# )

# %%
from sympy import cos, sin, ln, integrate, Symbol

x = Symbol('x')
integrate(2*x**3 + 3*x**2 - 5*x + 7*sin(x), x)
# Out:
# x**4/2 + x**3 - 5*x**2/2 - 7*cos(x)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin, cos, ln, oo, E
x = Symbol('x')
integrate(1/(x**2 + 1), (x, E, 100))
# Out:
# -atan(E) + atan(100)

# %%
from sympy import Symbol, integrate, sin, N
x = Symbol('x')
N(integrate(1/(x**2 + 1), (x, E, 100)))
# Out:
# 0.342513755090954
